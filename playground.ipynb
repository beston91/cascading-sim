# %%
import sys
sys.path.append('/graph_tiger')

# %%
from graph_tiger.cascading import Cascading
from graph_tiger.graphs import graph_loader

graph = graph_loader('BA', n=100, seed=1)

params = {
    'runs': 1,
    'steps': 100,
    'seed': 1,

    'l': 0.8,
    'r': 0.2,
    'c': int(0.1 * len(graph)),

    'k_a': 30,
    'attack': 'rb_node',
    'attack_approx': int(0.1 * len(graph)),

    'k_d': 0,
    'defense': None,

    'robust_measure': 'largest_connected_component',

    'plot_transition': True,  # False turns off key simulation image "snapshots"
    'gif_animation': True,  # True creaets a video of the simulation (MP4 file)
    'gif_snaps': False,  # True saves each frame of the simulation as an image

    'edge_style': 'bundled',
    'node_style': 'force_atlas',
    'fa_iter': 2000,
}

cascading = Cascading(graph, **params)
results = cascading.run_simulation()

cascading.plot_results(results)
# Out:
# Running simulation 1 times

# %%
# Out:
# Failed to start the Kernel.
#
# Canceled.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Failed to start the Kernel.
#
# Kernel m1-torch-py3.8 (Python 3.8.13) is not usable. Check the Jupyter output tab for more information.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
